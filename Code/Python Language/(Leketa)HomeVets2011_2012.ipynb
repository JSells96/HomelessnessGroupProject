# %% [markdown]
# ## IMPORT

# %%
import pandas as pd

# %%
import numpy as np
from scipy.stats import norm
from scipy import stats
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_excel("C:/Users/17082/OneDrive/Desktop/FINAL PROJECT DSO110/2011_2012HomeVets.xlsx")

# %% [markdown]
# # Delection of column ID

# %%
## dataframe = dataframe.drop(dataframe.columns[[0]],axis=1)
dataframe
# Out:
#     State  Homeless Veterans, 2012  Homeless Veterans, 2011
# 0      AK                      256                      288
# 1      AL                      526                      659
# 2      AR                      362                      411
# 3      AZ                     1478                     1528
# 4      CA                    14611                    16783
# 5      CO                     1512                     2074
# 6      CT                      332                      443
# 7      DC                      531                      515
# 8      DE                       66                       55
# 9      FL                     5331                     5644
# 10     GA                     2297                     2243
# 11     GU                       31                       33
# 12     HI                      507                      505
# 13     IA                      217                      267
# 14     ID                      260                      250
# ...

# %% [markdown]
# # Printing Column Names

# %%
list(dataframe.columns.values)
# Out:
# ['Homeless Veterans, 2012', 'Homeless Veterans, 2011']

# %% [markdown]
# # Checking for NA in dataset

# %%
dataframe.isna()
# Out:
#     Homeless Veterans, 2012  Homeless Veterans, 2011
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# 3                     False                    False
# 4                     False                    False
# 5                     False                    False
# 6                     False                    False
# 7                     False                    False
# 8                     False                    False
# 9                     False                    False
# 10                    False                    False
# 11                    False                    False
# 12                    False                    False
# 13                    False                    False
# 14                    False                    False
# 15                    False                    False
# 16                    False                    False
# ...

# %% [markdown]
# # Getting the count of missing data

# %%
dataframe.isna().sum()
# Out:
# Homeless Veterans, 2012    0
# Homeless Veterans, 2011    0
# dtype: int64

# %% [markdown]
# # Counting the States of Homeless Veterans

# %%
dataframe["Total"] = dataframe['Homeless Veterans, 2012'] + dataframe['Homeless Veterans, 2011']

# %%
## ColumnNames = ['State', 'Homeless Veterans, 2012','Homeless Veterans, 2011']
## dataframe = dataframe.reindex(columns = ColumnNames)

# %% [markdown]
# # Printing the data

# %%
dataframe
# Out:
#     State  Homeless Veterans, 2012  Homeless Veterans, 2011   Total
# 0      AK                      256                      288     544
# 1      AL                      526                      659    1185
# 2      AR                      362                      411     773
# 3      AZ                     1478                     1528    3006
# 4      CA                    14611                    16783   31394
# 5      CO                     1512                     2074    3586
# 6      CT                      332                      443     775
# 7      DC                      531                      515    1046
# 8      DE                       66                       55     121
# 9      FL                     5331                     5644   10975
# 10     GA                     2297                     2243    4540
# 11     GU                       31                       33      64
# 12     HI                      507                      505    1012
# ...

# %% [markdown]
# ## Histogram Plot

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(dataframe["Homeless Veterans, 2011"])
plt.xlabel("Count")
plt.ylabel("State")
plt.title("Homeless Veterans, 2011")
# Out:
# Text(0.5, 1.0, 'Homeless Veterans, 2011')

# %% [markdown]
# ## Bar Plot

# %%
plt.barh(dataframe['State'],dataframe['Homeless Veterans, 2011'],label = "State")
plt.xlabel("State")
plt.ylabel("count")
plt.title("Homeless Veterans 2011-2012")
# Out:
# Text(0.5, 1.0, 'Homeless Veterans 2011-2012')

# %%
df_sorted = dataframe.sort_values(by ='Total',ascending = True).tail(11)
df_sorted
# Out:
#     State  Homeless Veterans, 2012  Homeless Veterans, 2011   Total
# 38     OR                     1356                     1474    2830
# 39     PA                     1456                     1392    2848
# 50     WA                     1475                     1478    2953
# 3      AZ                     1478                     1528    3006
# 5      CO                     1512                     2074    3586
# 10     GA                     2297                     2243    4540
# 45     TX                     4364                     4891    9255
# 35     NY                     4961                     5765   10726
# 9      FL                     5331                     5644   10975
# 4      CA                    14611                    16783   31394
# 54  Total                    60579                    65455  126034

# %%
df_sorted.drop(index = df_sorted.index[-1],axis = 0,inplace = True)

# %%
plt.barh(df_sorted['State'],df_sorted['Homeless Veterans, 2011'])
plt.show()

# %%
plt.barh(df_sorted['State'],df_sorted['Homeless Veterans, 2012'])
plt.show()

# %%
df_sorted1 = dataframe.sort_values(by ='Total',ascending = True).head(10)
df_sorted1
# Out:
#    State  Homeless Veterans, 2012  Homeless Veterans, 2011  Total
# 11    GU                       31                       33     64
# 48    VI                       33                       32     65
# 8     DE                       66                       55    121
# 49    VT                      109                       81    190
# 41    RI                       96                      123    219
# 43    SD                      124                      109    233
# 22    ME                      116                      127    243
# 31    NH                      127                      126    253
# 40    PR                      116                      137    253
# 29    ND                      160                      124    284

# %%
plt.barh(df_sorted1['State'],df_sorted1['Homeless Veterans, 2011'])
plt.show()

# %%
plt.barh(df_sorted1['State'],df_sorted1['Homeless Veterans, 2012'])
plt.show()

# %%
pwd
