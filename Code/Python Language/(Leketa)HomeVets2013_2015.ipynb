# %% [markdown]
# ## Import

# %%
import pandas as pd

# %%
import numpy as np
from scipy.stats import norm
from scipy import stats
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_excel("C:/Users/17082/OneDrive/Desktop/FINAL PROJECT DSO110/2013_2015HomeVets.xlsx")

# %% [markdown]
# ## Delection of Column ID

# %%
##dataframe = dataframe.drop(dataframe.columns[[0]],axis=1)
dataframe
# Out:
#     State  Homeless Veterans, 2015  Homeless Veterans, 2014  \
# 0      AK                      180                      178
# 1      AL                      474                      542
# 2      AR                      456                      361
# 3      AZ                     1220                      858
# 4      CA                    11311                    12096
# 5      CO                      950                      753
# 6      CT                      282                      295
# 7      DC                      408                      406
# 8      DE                       79                       93
# 9      FL                     3926                     4552
# 10     GA                     1548                     1443
# 11     GU                       23                       36
# 12     HI                      692                      593
# 13     IA                      207                      202
# 14     ID                      249                      215
# ...

# %% [markdown]
# ## Printing Column Names

# %%
list(dataframe.columns.values)
# Out:
# ['State',
#  'Homeless Veterans, 2015',
#  'Homeless Veterans, 2014',
#  'Homeless Veterans, 2013']

# %% [markdown]
# ## Checking for NA in dataset

# %%
dataframe.isna()
# Out:
#     State  Homeless Veterans, 2015  Homeless Veterans, 2014  \
# 0   False                    False                    False
# 1   False                    False                    False
# 2   False                    False                    False
# 3   False                    False                    False
# 4   False                    False                    False
# 5   False                    False                    False
# 6   False                    False                    False
# 7   False                    False                    False
# 8   False                    False                    False
# 9   False                    False                    False
# 10  False                    False                    False
# 11  False                    False                    False
# 12  False                    False                    False
# 13  False                    False                    False
# 14  False                    False                    False
# ...

# %% [markdown]
# ## Getting the Count of Missing Data

# %%
dataframe.isna().sum()
# Out:
# State                      0
# Homeless Veterans, 2015    0
# Homeless Veterans, 2014    0
# Homeless Veterans, 2013    0
# dtype: int64

# %% [markdown]
# ## Counting the States of Homeless Veterans

# %%
dataframe["Total"] = dataframe['Homeless Veterans, 2013'] + dataframe['Homeless Veterans, 2014'] + dataframe['Homeless Veterans, 2015']

# %% [markdown]
# ## Printing the data

# %%
dataframe
# Out:
#     State  Homeless Veterans, 2015  Homeless Veterans, 2014  \
# 0      AK                      180                      178
# 1      AL                      474                      542
# 2      AR                      456                      361
# 3      AZ                     1220                      858
# 4      CA                    11311                    12096
# 5      CO                      950                      753
# 6      CT                      282                      295
# 7      DC                      408                      406
# 8      DE                       79                       93
# 9      FL                     3926                     4552
# 10     GA                     1548                     1443
# 11     GU                       23                       36
# 12     HI                      692                      593
# 13     IA                      207                      202
# 14     ID                      249                      215
# ...

# %% [markdown]
# ## Histogram Plot

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# df_sorted.drop(index = df_sorted.index[-1],axis = 0,inplace = True)

# %%
plt.barh(df_sorted['State'],df_sorted['Homeless Veterans, 2013'])
plt.show()

# %%
plt.barh(df_sorted['State'],df_sorted['Homeless Veterans, 2014'])
plt.show()

# %%
plt.barh(df_sorted['State'],df_sorted['Homeless Veterans, 2015'])
plt.show()

# %%
df_sorted1 = dataframe.sort_values(by ='Total',ascending = True).head(10)
df_sorted1
# Out:
#    State  Homeless Veterans, 2015  Homeless Veterans, 2014  \
# 11    GU                       23                       36
# 48    VI                       34                       32
# 8     DE                       79                       93
# 41    RI                      107                      108
# 40    PR                      164                       87
# 53    WY                      112                      116
# 49    VT                      119                      120
# 43    SD                      177                      132
# 31    NH                      138                      171
# 22    ME                      151                      152
#
#     Homeless Veterans, 2013  Total
# 11                       32     91
# 48                       33     99
# 8                        89    261
# 41                       97    312
# 40                       82    333
# 53                      137    365
# 49                      128    367
# ...

# %% [markdown]
# plt.barh(df_sorted1['State'],df_sorted1['Homeless Veterans, 2013'])
# plt.show()

# %%
plt.barh(df_sorted1['State'],df_sorted1['Homeless Veterans, 2014'])
plt.show()

# %%
plt.barh(df_sorted1['State'],df_sorted1['Homeless Veterans, 2015'])
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
df_sorted = dataframe.sort_values(by ='Total',ascending = True).tail(11)
df_sorted
# Out:
#     State  Homeless Veterans, 2015  Homeless Veterans, 2014  \
# 20     MA                     1133                     1264
# 15     IL                     1226                     1234
# 50     WA                     1293                     1433
# 39     PA                     1375                     1411
# 38     OR                     1464                     1292
# 10     GA                     1548                     1443
# 45     TX                     2393                     2718
# 35     NY                     2399                     2542
# 9      FL                     3926                     4552
# 4      CA                    11311                    12096
# 54  Total                    47725                    49689
#
#     Homeless Veterans, 2013   Total
# 20                     1253    3650
# 15                     1267    3727
# 50                     1318    4044
# 39                     1462    4248
# 38                     1494    4250
# ...

# %%
plt.hist(dataframe["Homeless Veterans, 2013"])
plt.xlabel("Count")
plt.ylabel("State")
plt.title("Homeless Veterans, 2013")
# Out:
# Text(0.5, 1.0, 'Homeless Veterans, 2013')
