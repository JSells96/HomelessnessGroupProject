# %% [markdown]
# ## IMPORT

# %%
import pandas as pd

# %%
import numpy as np
from scipy.stats import norm
from scipy import stats
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_excel("C:/Users/17082/OneDrive/Desktop/FINAL PROJECT DSO110/2016_2017HomeVets.xlsx")

# %% [markdown]
# ## Delection of Column ID

# %%
## dataframe = dataframe.drop(dataframe.columns[[0]],axis=1)

# %%
dataframe
# Out:
#     State  Homeless Veterans, 2017  Homeless Veterans, 2016
# 0      AK                      124                      168
# 1      AL                      269                      373
# 2      AR                      239                      222
# 3      AZ                      970                     1036
# 4      CA                    11436                     9612
# 5      CO                     1078                     1181
# 6      CT                      191                      216
# 7      DC                      285                      350
# 8      DE                       91                      107
# 9      FL                     2817                     2902
# 10     GA                      712                     1055
# 11     GU                       24                       21
# 12     HI                      615                      670
# 13     IA                      171                      170
# 14     ID                      228                      267
# ...

# %% [markdown]
# ## Printing Column Names

# %%
list(dataframe.columns.values)
# Out:
# ['State', 'Homeless Veterans, 2017', 'Homeless Veterans, 2016']

# %% [markdown]
# ## Checking for NA in dataset

# %%
dataframe.isna()
# Out:
#     State  Homeless Veterans, 2017  Homeless Veterans, 2016
# 0   False                    False                    False
# 1   False                    False                    False
# 2   False                    False                    False
# 3   False                    False                    False
# 4   False                    False                    False
# 5   False                    False                    False
# 6   False                    False                    False
# 7   False                    False                    False
# 8   False                    False                    False
# 9   False                    False                    False
# 10  False                    False                    False
# 11  False                    False                    False
# 12  False                    False                    False
# 13  False                    False                    False
# 14  False                    False                    False
# ...

# %% [markdown]
# ## Printing Column Names

# %%
list(dataframe.columns.values)
# Out:
# ['State', 'Homeless Veterans, 2017', 'Homeless Veterans, 2016', 'Total']

# %% [markdown]
# ## Getting the count of missing data

# %%
dataframe.isna().sum()
# Out:
# State                      0
# Homeless Veterans, 2017    0
# Homeless Veterans, 2016    0
# dtype: int64

# %% [markdown]
# ## Counting The States of Homeless Veterans

# %%
dataframe["Total"] = dataframe['Homeless Veterans, 2016'] + dataframe['Homeless Veterans, 2017']

# %% [markdown]
# ## Printing the data

# %%
dataframe
# Out:
#     State  Homeless Veterans, 2017  Homeless Veterans, 2016  Total
# 0      AK                      124                      168    292
# 1      AL                      269                      373    642
# 2      AR                      239                      222    461
# 3      AZ                      970                     1036   2006
# 4      CA                    11436                     9612  21048
# 5      CO                     1078                     1181   2259
# 6      CT                      191                      216    407
# 7      DC                      285                      350    635
# 8      DE                       91                      107    198
# 9      FL                     2817                     2902   5719
# 10     GA                      712                     1055   1767
# 11     GU                       24                       21     45
# 12     HI                      615                      670   1285
# ...

# %% [markdown]
# ## Histogram Plot

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(dataframe["Homeless Veterans, 2016"])
plt.xlabel("Count")
plt.ylabel("State")
plt.title("Homeless Veterans, 2016")
# Out:
# Text(0.5, 1.0, 'Homeless Veterans, 2016')

# %%
plt.hist(dataframe["Homeless Veterans, 2017"])
plt.xlabel("Count")
plt.ylabel("State")
plt.title("Homeless Veterans, 2017")
# Out:
# Text(0.5, 1.0, 'Homeless Veterans, 2017')

# %% [markdown]
# ## Bar Plot

# %%
plt.barh(dataframe['State'],dataframe['Homeless Veterans, 2016'],label = "State")
plt.xlabel("State")
plt.ylabel("count")
plt.title("Homeless Veterans 2016-2017")
# Out:
# Text(0.5, 1.0, 'Homeless Veterans 2016-2017')

# %%
df_sorted = dataframe.sort_values(by ='Total',ascending = True).tail(11)
df_sorted
# Out:
#     State  Homeless Veterans, 2017  Homeless Veterans, 2016  Total
# 28     NC                      931                      888   1819
# 3      AZ                      970                     1036   2006
# 39     PA                      963                     1136   2099
# 5      CO                     1078                     1181   2259
# 35     NY                     1244                     1248   2492
# 38     OR                     1251                     1341   2592
# 50     WA                     2093                     1484   3577
# 45     TX                     2200                     1768   3968
# 9      FL                     2817                     2902   5719
# 4      CA                    11436                     9612  21048
# 54  Total                    40020                    39471  79491

# %%
df_sorted.drop(index = df_sorted.index[-1],axis = 0,inplace = True)

# %%
plt.barh(df_sorted['State'],df_sorted['Homeless Veterans, 2016'])
plt.show()

# %%
plt.barh(df_sorted['State'],df_sorted['Homeless Veterans, 2017'])
plt.show()

# %%
df_sorted1 = dataframe.sort_values(by ='Total',ascending = True).head(10)
df_sorted1
# Out:
#    State  Homeless Veterans, 2017  Homeless Veterans, 2016  Total
# 11    GU                       24                       21     45
# 48    VI                       23                       32     55
# 53    WY                       63                       87    150
# 41    RI                       95                       89    184
# 29    ND                       74                      116    190
# 8     DE                       91                      107    198
# 26    MS                       57                      144    201
# 49    VT                       94                      110    204
# 40    PR                       94                      146    240
# 31    NH                      124                      123    247

# %%
plt.barh(df_sorted1['State'],df_sorted1['Homeless Veterans, 2016'])
plt.show()

# %%
plt.barh(df_sorted1['State'],df_sorted1['Homeless Veterans, 2017'])
plt.show()
