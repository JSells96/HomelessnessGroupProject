# %% [markdown]
# ## IMPORT

# %%
import pandas as pd

# %%
import numpy as np
from scipy.stats import norm
from scipy import stats
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_excel("C:/Users/17082/OneDrive/Desktop/FINAL PROJECT DSO110/2018_2019HomeVets.xlsx")

# %% [markdown]
# ## Delection of Column ID

# %%
## dataframe = dataframe.drop(dataframe.columns[[0]],axis=1)
dataframe
# Out:
#     State  Homeless Veterans, 2019  Homeless Veterans, 2018
# 0      AK                      111                      132
# 1      AL                      292                      339
# 2      AR                      238                      251
# 3      AZ                      910                      893
# 4      CA                    10980                    10836
# 5      CO                     1068                     1073
# 6      CT                      195                      190
# 7      DC                      297                      306
# 8      DE                       65                       70
# 9      FL                     2472                     2543
# 10     GA                      801                      705
# 11     GU                       23                       14
# 12     HI                      505                      532
# 13     IA                      149                      196
# 14     ID                      201                      215
# ...

# %% [markdown]
# ## Printing Column Names

# %%
list(dataframe.columns.values)
# Out:
# ['State', 'Homeless Veterans, 2019', 'Homeless Veterans, 2018']

# %% [markdown]
# ## Checking for NA in Dataset

# %%
dataframe.isna()
# Out:
#     State  Homeless Veterans, 2019  Homeless Veterans, 2018
# 0   False                    False                    False
# 1   False                    False                    False
# 2   False                    False                    False
# 3   False                    False                    False
# 4   False                    False                    False
# 5   False                    False                    False
# 6   False                    False                    False
# 7   False                    False                    False
# 8   False                    False                    False
# 9   False                    False                    False
# 10  False                    False                    False
# 11  False                    False                    False
# 12  False                    False                    False
# 13  False                    False                    False
# 14  False                    False                    False
# ...

# %% [markdown]
# ## Getting the Count of Missing Data

# %%
dataframe.isna().sum()
# Out:
# State                      0
# Homeless Veterans, 2019    0
# Homeless Veterans, 2018    0
# dtype: int64

# %% [markdown]
# ## Counting the States of Homeless Veterans

# %%
dataframe["Total"] = dataframe['Homeless Veterans, 2018'] + dataframe['Homeless Veterans, 2019']

# %%
## ColumnNames = ['State', 'Homeless Veterans, 2012','Homeless Veterans, 2011']
## dataframe = dataframe.reindex(columns = ColumnNames)

# %% [markdown]
# ## Printing the Data

# %%
dataframe
# Out:
#     State  Homeless Veterans, 2019  Homeless Veterans, 2018  Total
# 0      AK                      111                      132    243
# 1      AL                      292                      339    631
# 2      AR                      238                      251    489
# 3      AZ                      910                      893   1803
# 4      CA                    10980                    10836  21816
# 5      CO                     1068                     1073   2141
# 6      CT                      195                      190    385
# 7      DC                      297                      306    603
# 8      DE                       65                       70    135
# 9      FL                     2472                     2543   5015
# 10     GA                      801                      705   1506
# 11     GU                       23                       14     37
# 12     HI                      505                      532   1037
# ...

# %% [markdown]
# ## Histogram Plot

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(dataframe["Homeless Veterans, 2018"])
plt.xlabel("Count")
plt.ylabel("State")
plt.title("Homeless Veterans, 2018")
# Out:
# Text(0.5, 1.0, 'Homeless Veterans, 2018')

# %%
plt.hist(dataframe["Homeless Veterans, 2019"])
plt.xlabel("Count")
plt.ylabel("State")
plt.title("Homeless Veterans, 2019")
# Out:
# Text(0.5, 1.0, 'Homeless Veterans, 2019')

# %% [markdown]
# ## Bar Plot

# %%
plt.barh(dataframe['State'],dataframe['Homeless Veterans, 2018'],label = "State")
plt.xlabel("State")
plt.ylabel("count")
plt.title("Homeless Veterans 2018-2019")
# Out:
# Text(0.5, 1.0, 'Homeless Veterans 2018-2019')

# %%
df_sorted = dataframe.sort_values(by ='Total',ascending = True).tail(11)
df_sorted
# Out:
#     State  Homeless Veterans, 2019  Homeless Veterans, 2018  Total
# 3      AZ                      910                      893   1803
# 39     PA                      857                      982   1839
# 20     MA                      917                      985   1902
# 5      CO                     1068                     1073   2141
# 35     NY                     1270                     1224   2494
# 38     OR                     1438                     1363   2801
# 50     WA                     1585                     1636   3221
# 45     TX                     1806                     1935   3741
# 9      FL                     2472                     2543   5015
# 4      CA                    10980                    10836  21816
# 54  Total                    37085                    37878  74963

# %%
df_sorted.drop(index = df_sorted.index[-1],axis = 0,inplace = True)

# %%
plt.barh(df_sorted['State'],df_sorted['Homeless Veterans, 2018'])
plt.show()

# %%
plt.barh(df_sorted['State'],df_sorted['Homeless Veterans, 2019'])
plt.show()

# %%
df_sorted1 = dataframe.sort_values(by ='Total',ascending = True).head(10)
df_sorted1
# Out:
#    State  Homeless Veterans, 2019  Homeless Veterans, 2018  Total
# 48    VI                       13                       24     37
# 11    GU                       23                       14     37
# 29    ND                       49                        9     58
# 53    WY                       51                       47     98
# 8     DE                       65                       70    135
# 40    PR                       90                       82    172
# 26    MS                       72                      102    174
# 43    SD                       66                      110    176
# 49    VT                       87                      104    191
# 41    RI                       92                      103    195

# %%
plt.barh(df_sorted1['State'],df_sorted1['Homeless Veterans, 2018'])
plt.show()

# %%
plt.barh(df_sorted1['State'],df_sorted1['Homeless Veterans, 2019'])
plt.show()
