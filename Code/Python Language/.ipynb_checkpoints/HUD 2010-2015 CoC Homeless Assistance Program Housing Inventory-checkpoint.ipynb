# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Importing Data

# %%
coc2010 = pd.read_excel ('../../Data/HUD 2010 CoC Homeless Assistance Program Housing Inventory Report.xls')
coc2011 = pd.read_excel ('../../Data/HUD 2011 CoC Homeless Assistance Program Housing Inventory Report.xls')
coc2012 = pd.read_excel ('../../Data/HUD 2012 CoC Homeless Assistance Program Housing Inventory Report.xls')
coc2013 = pd.read_excel ('../../Data/HUD 2013 CoC Homeless Assistance Program Housing Inventory Report.xls')
coc2014 = pd.read_excel ('../../Data/HUD 2014 CoC Homeless Assistance Program Housing Inventory Report.xls')
coc2015 = pd.read_excel ('../../Data/HUD 2015 CoC Homeless Assistance Program Housing Inventory Report.xls')

# %%
print (coc2010)
print (coc2011)
print (coc2012)
print (coc2013)
print (coc2014)
print (coc2015)
# Out:
#   HUD 2010 CoC Homeless Assistance Program Housing Inventory Report  \
# 0    Emergency, Safe Haven and Transitional Housing
# 1                                 Emergency Shelter
# 2                                         Safe Haven
# 3                               Transitional Housing
# 4                                   Rapid Re-Housing
# 5                       Permanent Supportive Housing
# 6                                        Grand Total
#
#    Family Units  Family Beds  Individual Beds  Total Yr Round Beds  Seasonal  \
# 0       68063.0     217462.0           206970               424432   19668.0
# 1       32878.0     107950.0           113660               221610   19668.0
# 2           NaN          NaN             2199                 2199       NaN
# 3       35185.0     109512.0            91111               200623       NaN
# 4        5070.0      14790.0             5052                19842       NaN
# ...

# %%
coc2010_2011 = pd.merge(coc2010, coc2011)

# %%
coc2012_2013 = pd.merge(coc2010_2011, coc2013)

# %%
coc2013 = pd.merge(coc2012, coc2012_2013)

# %%
coc2014 = pd.merge(coc2012_2013, coc2014)

# %%
coc2014
# Out:
# Empty DataFrame
# Columns: [HUD 2010 CoC Homeless Assistance Program Housing Inventory Report, Individual Beds, HUD 2011 CoC Homeless Assistance Program Housing Inventory, HUD 2013 CoC Homeless Assistance Program Housing Inventory, HUD 2014 CoC Homeless Assistance Program Housing Inventory Report, Family Units, Family Beds, Adult Only Beds, Child Only Beds, Total Yr Round Beds, Seasonal, Overflow/Voucher, Veteran Beds, Youth Beds]
# Index: []

# %%
coc2014a = pd.merge(coc2013, coc2014)

# %%
coc2014a
# Out:
# Empty DataFrame
# Columns: [HUD 2012 CoC Homeless Assistance Program Housing Inventory Report, HUD 2010 CoC Homeless Assistance Program Housing Inventory Report, Individual Beds, HUD 2011 CoC Homeless Assistance Program Housing Inventory, HUD 2013 CoC Homeless Assistance Program Housing Inventory, HUD 2014 CoC Homeless Assistance Program Housing Inventory Report, Family Units, Family Beds, Adult Only Beds, Child Only Beds, Total Yr Round Beds, Seasonal, Overflow/Voucher, Veteran Beds, Youth Beds]
# Index: []

# %%
coc2010_2015 = pd.merge (coc2014a, coc2015)

# %%
coc2010_2015.head()
# Out:
# Empty DataFrame
# Columns: [HUD 2012 CoC Homeless Assistance Program Housing Inventory Report, HUD 2010 CoC Homeless Assistance Program Housing Inventory Report, Individual Beds, HUD 2011 CoC Homeless Assistance Program Housing Inventory, HUD 2013 CoC Homeless Assistance Program Housing Inventory, HUD 2014 CoC Homeless Assistance Program Housing Inventory Report, HUD 2015 CoC Homeless Assistance Program Housing Inventory Report, Family Units, Family Beds, Adult Only Beds, Child Only Beds, Total Yr Round Beds, Seasonal, Overflow/Voucher, Veteran Beds, Youth Beds]
# Index: []

# %%
coc2010_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 16 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   HUD 2012 CoC Homeless Assistance Program Housing Inventory Report  0 non-null      object
#  1   HUD 2010 CoC Homeless Assistance Program Housing Inventory Report  0 non-null      object
#  2   Individual Beds                                                    0 non-null      int64
#  3   HUD 2011 CoC Homeless Assistance Program Housing Inventory         0 non-null      object
#  4   HUD 2013 CoC Homeless Assistance Program Housing Inventory         0 non-null      object
#  5   HUD 2014 CoC Homeless Assistance Program Housing Inventory Report  0 non-null      object
#  6   HUD 2015 CoC Homeless Assistance Program Housing Inventory Report  0 non-null      object
# ...

# %%
coc2010_2015.dropna()
# Out:
# Empty DataFrame
# Columns: [HUD 2012 CoC Homeless Assistance Program Housing Inventory Report, HUD 2010 CoC Homeless Assistance Program Housing Inventory Report, Individual Beds, HUD 2011 CoC Homeless Assistance Program Housing Inventory, HUD 2013 CoC Homeless Assistance Program Housing Inventory, HUD 2014 CoC Homeless Assistance Program Housing Inventory Report, HUD 2015 CoC Homeless Assistance Program Housing Inventory Report, Family Units, Family Beds, Adult Only Beds, Child Only Beds, Total Yr Round Beds, Seasonal, Overflow/Voucher, Veteran Beds, Youth Beds]
# Index: []

# %%
coc2010_2015.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Individual Beds'}>,
#         <AxesSubplot:title={'center':'Family Units'}>,
#         <AxesSubplot:title={'center':'Family Beds'}>],
#        [<AxesSubplot:title={'center':'Adult Only Beds'}>,
#         <AxesSubplot:title={'center':'Child Only Beds'}>,
#         <AxesSubplot:title={'center':'Total Yr Round Beds'}>],
#        [<AxesSubplot:title={'center':'Seasonal'}>,
#         <AxesSubplot:title={'center':'Overflow/Voucher'}>,
#         <AxesSubplot:title={'center':'Veteran Beds'}>],
#        [<AxesSubplot:title={'center':'Youth Beds'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.pairplot(coc2010_2015)

# %%
import pylab
import scipy.stats as stats

# %%
coc2010_2015 = np.random.normal(loc = 20, scale=5, size=150)
stats.probplot(coc2010_2015, dist="norm", plot=pylab)
pylab.show()

# %%
coc2010_2015 = np.random.normal(loc = 20, scale=5, size=150)
ax = sns.distplot(coc2010_2015)
# Out:
# /Users/lakisha/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from scipy.stats import chisquare
import numpy as np

# %%
coc2010_2015= np.random.normal(loc = 20, scale=5, size=150)
statistic,pvalue=chisquare(coc2010_2015)
print('statistics=%.3f, p=%.3f\n' % (statistic, pvalue))
if pvalue > 0.05:
    print('Normal Distribution')
else:
    print('Not Normal Distribution')
# Out:
# statistics=166.107, p=0.160
#
# Normal Distribution
