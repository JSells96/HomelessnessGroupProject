# %% [markdown]
# ## Analysing Homeless Population

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import seaborn as sns
# %matplotlib inline
import  statsmodels.api as sm
import statsmodels.stats.api as sms
from scipy.stats import boxcox

# %% [markdown]
# uploading data

# %%
homeless_population = pd.read_excel("../../Data/homeless_population_usafacts.xlsx")
homeless_population.head()
# Out:
#                                Years 1980 1981 1982 1983 1984 1985 1986  1987  \
# 0               Homeless population   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1                By living situation  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2                         Sheltered   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3              By family arrangement  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4                      Individuals    NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
#    1988  ...      2011      2012      2013      2014      2015      2016  \
# 0   NaN  ...  623788.0  621553.0  590364.0  576450.0  564708.0  549928.0
# 1   NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 2   NaN  ...  392316.0  390155.0  394698.0  401051.0  391440.0  373571.0
# 3   NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 4   NaN  ...  205834.0  199159.0  203127.0  209148.0  205616.0  198008.0
#
#        2017      2018      2019      2020
# ...

# %% [markdown]
# ## Wrangling Data
# dropping any empty columns and NAs.

# %%
homeless_population.drop([1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004], axis=1, inplace = True)
homeless_population.head()
# Out:
#                                Years      2005      2006      2007      2008  \
# 0               Homeless population   754147.0  759101.0  647258.0  639784.0
# 1                By living situation       NaN       NaN       NaN       NaN
# 2                         Sheltered   415366.0  427971.0  391401.0  386361.0
# 3              By family arrangement       NaN       NaN       NaN       NaN
# 4                      Individuals         NaN  224293.0  213073.0  204855.0
#
#        2009      2010      2011      2012      2013      2014      2015  \
# 0  630227.0  637077.0  623788.0  621553.0  590364.0  576450.0  564708.0
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  403308.0  403543.0  392316.0  390155.0  394698.0  401051.0  391440.0
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4  215995.0  212218.0  205834.0  199159.0  203127.0  209148.0  205616.0
#
#        2016      2017      2018      2019      2020
# ...

# %%
homeless_population2 = homeless_population.dropna()
homeless_population2.head(10)
# Out:
#                                                Years      2005      2006  \
# 0                               Homeless population   754147.0  759101.0
# 2                                         Sheltered   415366.0  427971.0
# 6                                       Unsheltered   338781.0  331130.0
# 8                                      Individuals    223027.0  228287.0
# 9                  People in families with children   115754.0  102843.0
#
#        2007      2008      2009      2010      2011      2012      2013  \
# 0  647258.0  639784.0  630227.0  637077.0  623788.0  621553.0  590364.0
# 2  391401.0  386361.0  403308.0  403543.0  392316.0  390155.0  394698.0
# 6  255857.0  253423.0  226919.0  233534.0  231472.0  231398.0  195666.0
# 8  199627.0  199670.0  176136.0  182922.0  181779.0  182997.0  165047.0
# 9   56230.0   53753.0   50783.0   50612.0   49693.0   48401.0   30619.0
#
#        2014      2015      2016      2017      2018      2019      2020
# ...

# %%
homeless_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Years   83 non-null     object
#  1   2005    5 non-null      float64
#  2   2006    7 non-null      float64
#  3   2007    58 non-null     float64
#  4   2008    58 non-null     float64
#  5   2009    58 non-null     float64
#  6   2010    58 non-null     float64
#  7   2011    58 non-null     float64
#  8   2012    58 non-null     float64
#  9   2013    58 non-null     float64
#  10  2014    58 non-null     float64
#  11  2015    72 non-null     float64
#  12  2016    72 non-null     float64
#  13  2017    73 non-null     float64
#  14  2018    73 non-null     float64
#  15  2019    73 non-null     float64
#  16  2020    73 non-null     float64
# dtypes: float64(16), object(1)
# memory usage: 11.5+ KB

# %%
def YearsR (series):
    if series == "Homeless population":
        return 1
    if series == "Sheltered":
        return 2
    if series == "Individuals":
        return 3
    if series == "People in families with children":
        return 4
    if series == "Unsheltered":
        return 5
    if series == "Under 18":
        return 6
    if series == "18 to 24":
        return 7
    if series == "over 24":
        return 8
    if series == "Cisgender women":
        return 9
    if series == "Cisgender men":
        return 10
    if series == "Transgender people":
        return 11
    if series == "Gender non-conforming":
        return 12
    if series == "White":
        return 13
    if series == "Black":
        return 14
    if series == "Asian":
        return 15
    if series == "Native American":
        return 16
    if series == "Pacific Islander":
        return 17
    if series == "Multiple races":
        return 18
    if series == "Non-Hispanic":
        return 19
    if series == "Hispanic":
        return 20
    if series == "Alabama":
        return 21
    if series == "Alaska":
        return 22
    if series == "Arizona":
        return 23
    if series == "Arkansas":
        return 24
    if series == "California":
        return 25
    if series == "Colorado":
        return 26
    if series == "Connecticut":
        return 27
    if series == "Delaware":
        return 28
    if series == "Distric of Columbia":
        return 29
    if series == "Florida":
        return 30
    if series == "Georgia":
        return 31
    if series == "Hawaii":
        return 32
    if series == "Idaho":
        return 33
    if series == "Illinois":
        return 34
    if series == "Indiana":
        return 35
    if series == "Iowa":
        return 36
    if series == "Kansas":
        return 37
    if series == "Kentuckey":
        return 38
    if series == "Louisiana":
        return 39
    if series == "Maine":
        return 40
    if series == "Maryland":
        return 41
    if series == "Massachusetts":
        return 42
    if series == "Michigan":
        return 43
    if series == "Minnesota":
        return 44
    if series == "Mississippi":
        return 45
    if series == "Missouri":
        return 46
    if series == "Montana":
        return 47
    if series == "Nebraska":
        return 48
    if series == "Nevada":
        return 49
    if series == " New Hampshire":
        return 50
    if series == "New Jersey":
        return 51
    if series == "New Mexico":
        return 52
    if series == "New York":
        return 53
    if series == "North Carolina":
        return 54
    if series == "North Dakota":
        return 55
    if series == "Ohio":
        return 56
    if series == "Oklahoma":
        return 57
    if series == "Oregon":
        return 58
    if series == "Pennsylvania":
        return 59
    if series == "Rhode Island":
        return 60
    if series == "South Carolina":
        return 61
    if series == "South Dakota":
        return 62
    if series == "Tennessee":
        return 63
    if series == "Texas":
        return 64
    if series == "Utah":
        return 65
    if series == "Vermont":
        return 66
    if series == "Virginia":
        return 67
    if series == "Washington":
        return 68
    if series == "West Virginia":
        return 69
    if series == "Wisconsin":
        return 70
    if series == "Wyoming":
        return 71
    
homeless_population2['Years']=homeless_population2['Years'].apply(YearsR)
homeless_population2['Years'].value_counts()
# Out:
# C:\Users\hanyu\AppData\Local\Temp/ipykernel_9344/1411682885.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   homeless_population2['Years']=homeless_population2['Years'].apply(YearsR)
# Series([], Name: Years, dtype: int64)

# %%
homeless_population2.head()
# Out:
#   Years      2005      2006      2007      2008      2009      2010      2011  \
# 0  None  754147.0  759101.0  647258.0  639784.0  630227.0  637077.0  623788.0
# 2  None  415366.0  427971.0  391401.0  386361.0  403308.0  403543.0  392316.0
# 6  None  338781.0  331130.0  255857.0  253423.0  226919.0  233534.0  231472.0
# 8  None  223027.0  228287.0  199627.0  199670.0  176136.0  182922.0  181779.0
# 9  None  115754.0  102843.0   56230.0   53753.0   50783.0   50612.0   49693.0
#
#        2012      2013      2014      2015      2016      2017      2018  \
# 0  621553.0  590364.0  576450.0  564708.0  549928.0  550996.0  552830.0
# 2  390155.0  394698.0  401051.0  391440.0  373571.0  360867.0  358363.0
# 6  231398.0  195666.0  175399.0  173268.0  176357.0  190129.0  194467.0
# 8  182997.0  165047.0  151041.0  152806.0  157204.0  173441.0  178077.0
# 9   48401.0   30619.0   24358.0   20462.0   19153.0   16688.0   16390.0
#
#        2019      2020
# 0  567715.0  580466.0
# ...

# %% [markdown]
# ## testing for Linearity and Normality

# %%
sns.pairplot(homeless_population2)

# %%
sns.distplot(homeless_population2)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Testing for Homoscedasticity

# %%
x = homeless_population2[['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']]
y = homeless_population2['Years']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9344/2652992402.py in <module>
# ----> 1 x = homeless_population2[['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']]
#       2 y = homeless_population2['Years']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
# ...
