# %% [markdown]
# ## Running a Corrolation for the Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# importing Data

# %%
Homeless_population = pd.read_excel("../../Data/homeless_population_usafacts.xlsx")
Homeless_population.head()
# Out:
#                                Years 1980 1981 1982 1983 1984 1985 1986  1987  \
# 0            Homeless population (1)  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1                By living situation  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2                      Sheltered (1)  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3              By family arrangement  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4                   Individuals  (1)  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
#    1988  ...      2011      2012      2013      2014      2015      2016  \
# 0   NaN  ...  623788.0  621553.0  590364.0  576450.0  564708.0  549928.0
# 1   NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 2   NaN  ...  392316.0  390155.0  394698.0  401051.0  391440.0  373571.0
# 3   NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 4   NaN  ...  205834.0  199159.0  203127.0  209148.0  205616.0  198008.0
#
#        2017      2018      2019      2020
# ...

# %%
Homeless_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 42 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Years   83 non-null     object
#  1   1980    2 non-null      object
#  2   1981    2 non-null      object
#  3   1982    1 non-null      object
#  4   1983    2 non-null      object
#  5   1984    1 non-null      object
#  6   1985    2 non-null      object
#  7   1986    2 non-null      object
#  8   1987    0 non-null      float64
#  9   1988    0 non-null      float64
#  10  1989    0 non-null      float64
#  11  1990    0 non-null      float64
#  12  1991    0 non-null      float64
#  13  1992    0 non-null      float64
#  14  1993    0 non-null      float64
#  15  1994    0 non-null      float64
#  16  1995    0 non-null      float64
#  17  1996    0 non-null      float64
#  18  1997    0 non-null      float64
#  19  1998    0 non-null      float64
#  20  1999    0 non-null      float64
# ...

# %%
Homeless_population.drop([1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004], axis=1, inplace = True)

# %%
Homeless_population.head()
# Out:
#                                Years      2005      2006      2007      2008  \
# 0            Homeless population (1)  754147.0  759101.0  647258.0  639784.0
# 1                By living situation       NaN       NaN       NaN       NaN
# 2                      Sheltered (1)  415366.0  427971.0  391401.0  386361.0
# 3              By family arrangement       NaN       NaN       NaN       NaN
# 4                   Individuals  (1)       NaN  224293.0  213073.0  204855.0
#
#        2009      2010      2011      2012      2013      2014      2015  \
# 0  630227.0  637077.0  623788.0  621553.0  590364.0  576450.0  564708.0
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  403308.0  403543.0  392316.0  390155.0  394698.0  401051.0  391440.0
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4  215995.0  212218.0  205834.0  199159.0  203127.0  209148.0  205616.0
#
#        2016      2017      2018      2019      2020
# ...

# %%
Homeless_population1= Homeless_population.dropna()
Homeless_population1.head()
# Out:
#                                                Years      2005      2006  \
# 0                            Homeless population (1)  754147.0  759101.0
# 2                                      Sheltered (1)  415366.0  427971.0
# 6                                    Unsheltered (1)  338781.0  331130.0
# 8                                   Individuals  (1)  223027.0  228287.0
# 9                  People in families with childr...  115754.0  102843.0
#
#        2007      2008      2009      2010      2011      2012      2013  \
# 0  647258.0  639784.0  630227.0  637077.0  623788.0  621553.0  590364.0
# 2  391401.0  386361.0  403308.0  403543.0  392316.0  390155.0  394698.0
# 6  255857.0  253423.0  226919.0  233534.0  231472.0  231398.0  195666.0
# 8  199627.0  199670.0  176136.0  182922.0  181779.0  182997.0  165047.0
# 9   56230.0   53753.0   50783.0   50612.0   49693.0   48401.0   30619.0
#
#        2014      2015      2016      2017      2018      2019      2020
# ...

# %% [markdown]
# Doing a Pearson Corrolation

# %%
Homeless_population1.corr(method='pearson')
# Out:
#           2005      2006      2007      2008      2009      2010      2011  \
# 2005  1.000000  0.999354  0.991283  0.990959  0.983534  0.985097  0.986157
# 2006  0.999354  1.000000  0.995356  0.995136  0.988782  0.990234  0.991173
# 2007  0.991283  0.995356  1.000000  0.999976  0.997394  0.998350  0.998847
# 2008  0.990959  0.995136  0.999976  1.000000  0.997067  0.998107  0.998650
# 2009  0.983534  0.988782  0.997394  0.997067  1.000000  0.999881  0.999688
# 2010  0.985097  0.990234  0.998350  0.998107  0.999881  1.000000  0.999954
# 2011  0.986157  0.991173  0.998847  0.998650  0.999688  0.999954  1.000000
# 2012  0.986221  0.991283  0.999011  0.998851  0.999554  0.999896  0.999985
# 2013  0.972624  0.979703  0.993395  0.993135  0.998570  0.998081  0.997589
# 2014  0.962501  0.970505  0.987177  0.986764  0.995623  0.994485  0.993566
# 2015  0.962909  0.971094  0.988073  0.987758  0.995817  0.994867  0.994052
# ...

# %%
Homeless_population1.corr(method = 'pearson').style.format("{:2}").background_gradient(cmap=plt.get_cmap('coolwarm'),axis=1)
# Out:
# <style type="text/css">
# #T_ff57f_row0_col0, #T_ff57f_row1_col1, #T_ff57f_row2_col2, #T_ff57f_row2_col3, #T_ff57f_row3_col2, #T_ff57f_row3_col3, #T_ff57f_row4_col4, #T_ff57f_row5_col5, #T_ff57f_row5_col6, #T_ff57f_row6_col5, #T_ff57f_row6_col6, #T_ff57f_row6_col7, #T_ff57f_row7_col6, #T_ff57f_row7_col7, #T_ff57f_row8_col8, #T_ff57f_row9_col9, #T_ff57f_row9_col10, #T_ff57f_row10_col9, #T_ff57f_row10_col10, #T_ff57f_row11_col11, #T_ff57f_row12_col12, #T_ff57f_row13_col13, #T_ff57f_row14_col14, #T_ff57f_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ff57f_row0_col1, #T_ff57f_row4_col6 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_ff57f_row0_col2, #T_ff57f_row4_col13 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_ff57f_row0_col3, #T_ff57f_row8_col2, #T_ff57f_row13_col9 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_ff57f_row0_col4, #T_ff57f_row4_col14 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# ...

# %% [markdown]
# we can see that the matrix corrolation show us that the homeless population has a very strong correlation throughout the years.

# %%
Homeless_population1.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2005'}>,
#         <AxesSubplot:title={'center':'2006'}>,
#         <AxesSubplot:title={'center':'2007'}>,
#         <AxesSubplot:title={'center':'2008'}>],
#        [<AxesSubplot:title={'center':'2009'}>,
#         <AxesSubplot:title={'center':'2010'}>,
#         <AxesSubplot:title={'center':'2011'}>,
#         <AxesSubplot:title={'center':'2012'}>],
#        [<AxesSubplot:title={'center':'2013'}>,
#         <AxesSubplot:title={'center':'2014'}>,
#         <AxesSubplot:title={'center':'2015'}>,
#         <AxesSubplot:title={'center':'2016'}>],
#        [<AxesSubplot:title={'center':'2017'}>,
#         <AxesSubplot:title={'center':'2018'}>,
#         <AxesSubplot:title={'center':'2019'}>,
#         <AxesSubplot:title={'center':'2020'}>]], dtype=object)

# %%
sns.heatmap(Homeless_population1.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that there have been some years in which the Homeless population has decreased but over all it is a very small difference between the Homeless population each year.

# %%
Homeless_population1.corr(method = 'spearman').style.format("{:2}").background_gradient(cmap=plt.get_cmap('coolwarm'),axis=1)
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# We can deduct that each year is a perfect positive correlation between the population.
