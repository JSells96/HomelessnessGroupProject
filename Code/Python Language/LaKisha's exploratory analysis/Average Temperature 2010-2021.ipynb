# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Importing Data

# %%
Temp = pd.read_excel('../../Data/AvgTemp.xlsx')

# %%
print (Temp)
# Out:
#     Years  Alabama  Alaska  Arizona  Arkansas  California  Colorodo  \
# 0    2021     64.2    26.5     62.2      61.2        60.3      47.5
# 1    2020     64.9    27.5     62.6      61.1        60.5      47.3
# 2    2019     65.4    32.2     60.3      61.2        58.4      45.3
# 3    2018     64.5    30.4     62.3      61.2        60.1      47.2
# 4    2017     65.0    29.3     63.0      62.5        60.3      47.9
# 5    2016     65.3    31.9     62.2      62.8        60.1      47.3
# 6    2015     64.6    30.0     61.8      61.4        60.8      47.4
# 7    2014     62.0    30.3     62.2      58.7        61.4      46.1
# 8    2013     62.6    27.8     60.4      59.6        59.3      45.1
# 9    2012     64.9    24.3     62.1      63.6        59.5      48.3
# 10   2011     63.8    27.0     60.3      61.8        57.4      45.4
# 11   2010     62.7    27.4     60.4      61.2        57.7      46.2
#
#     Connecticut  Delaware  Florida  ...  South Dakota  Tennessee  Texas  Utah  \
# ...

# %%
Temp.head()
# Out:
#    Unnamed: 0  Alabama  Alaska  Arizona  Arkansas  California  Colorodo  \
# 0        2021     64.2    26.5     62.2      61.2        60.3      47.5
# 1        2020     64.9    27.5     62.6      61.1        60.5      47.3
# 2        2019     65.4    32.2     60.3      61.2        58.4      45.3
# 3        2018     64.5    30.4     62.3      61.2        60.1      47.2
# 4        2017     65.0    29.3     63.0      62.5        60.3      47.9
#
#    Connecticut  Delaware  Florida  ...  South Dakota  Tennessee  Texas  Utah  \
# 0         51.4      57.4     72.2  ...          45.1       59.1   66.2  50.7
# 1         51.8      58.0     73.2  ...          44.8       59.3   66.9  50.4
# 2         49.8      57.5     73.2  ...          49.3       59.8   65.9  47.9
# 3         50.8      57.1     72.3  ...          44.0       59.1   66.0  50.4
# 4         50.9      57.6     72.8  ...          43.7       60.0   67.3  50.7
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming
# ...

# %% [markdown]
# # Histogram

# %%
Temp.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'Alabama'}>,
#         <AxesSubplot:title={'center':'Alaska'}>,
#         <AxesSubplot:title={'center':'Arizona'}>,
#         <AxesSubplot:title={'center':'Arkansas'}>,
#         <AxesSubplot:title={'center':'California'}>,
#         <AxesSubplot:title={'center':'Colorodo'}>],
#        [<AxesSubplot:title={'center':'Connecticut'}>,
#         <AxesSubplot:title={'center':'Delaware'}>,
#         <AxesSubplot:title={'center':'Florida'}>,
#         <AxesSubplot:title={'center':'Georgia'}>,
#         <AxesSubplot:title={'center':'Idaho'}>,
#         <AxesSubplot:title={'center':'Illinois'}>,
#         <AxesSubplot:title={'center':'Indiana'}>],
#        [<AxesSubplot:title={'center':'Iowa'}>,
#         <AxesSubplot:title={'center':'Kansas'}>,
#         <AxesSubplot:title={'center':'Kentucky'}>,
#         <AxesSubplot:title={'center':'Louisiana'}>,
#         <AxesSubplot:title={'center':'Maine'}>,
# ...

# %%
sns.pairplot(Temp)

# %% [markdown]
# # Checking for Normal Distribution

# %%
import pylab
import scipy.stats as stats

# %%
Temp = np.random.normal(loc = 20, scale=5, size=150)
stats.probplot(Temp, dist="norm", plot=pylab)
pylab.show()

# %%
Temp = np.random.normal(loc = 20, scale=5, size=150)
ax = sns.distplot(Temp)
# Out:
# /Users/lakisha/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Testing for normailty using Chi-Square

# %%
from scipy.stats import chisquare
import numpy as np

# %%
Temp= np.random.normal(loc = 20, scale=5, size=150)
statistic,pvalue=chisquare(Temp)
print('statistics=%.3f, p=%.3f\n' % (statistic, pvalue))
if pvalue > 0.05:
    print('Normal Distribution')
else:
    print('Not Normal Distribution')
# Out:
# statistics=171.543, p=0.100
#
# Normal Distribution
