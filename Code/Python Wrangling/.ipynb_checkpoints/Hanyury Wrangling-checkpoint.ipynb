# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Importing Data

# %%
homeless_pop = pd.read_excel("../../Data/homeless_population_usafacts.xlsx")
homeless_pop.head()
# Out:
#                                Years 1980 1981 1982 1983 1984 1985 1986  1987  \
# 0            Homeless population (1)  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1                By living situation  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2                      Sheltered (1)  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3              By family arrangement  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4                   Individuals  (1)  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
#    1988  ...      2011      2012      2013      2014      2015      2016  \
# 0   NaN  ...  623788.0  621553.0  590364.0  576450.0  564708.0  549928.0
# 1   NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 2   NaN  ...  392316.0  390155.0  394698.0  401051.0  391440.0  373571.0
# 3   NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 4   NaN  ...  205834.0  199159.0  203127.0  209148.0  205616.0  198008.0
#
#        2017      2018      2019      2020
# ...

# %% [markdown]
# pulling the info() to see the names of the columns that need to be drop

# %%
homeless_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 42 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Years   83 non-null     object
#  1   1980    2 non-null      object
#  2   1981    2 non-null      object
#  3   1982    1 non-null      object
#  4   1983    2 non-null      object
#  5   1984    1 non-null      object
#  6   1985    2 non-null      object
#  7   1986    2 non-null      object
#  8   1987    0 non-null      float64
#  9   1988    0 non-null      float64
#  10  1989    0 non-null      float64
#  11  1990    0 non-null      float64
#  12  1991    0 non-null      float64
#  13  1992    0 non-null      float64
#  14  1993    0 non-null      float64
#  15  1994    0 non-null      float64
#  16  1995    0 non-null      float64
#  17  1996    0 non-null      float64
#  18  1997    0 non-null      float64
#  19  1998    0 non-null      float64
#  20  1999    0 non-null      float64
# ...

# %% [markdown]
# Dropping multiple columns using the column index number

# %%
homeless_pop.drop([1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004], axis=1, inplace = True)

# %%
homeless_pop.head()
# Out:
#                                Years      2005      2006      2007      2008  \
# 0            Homeless population (1)  754147.0  759101.0  647258.0  639784.0
# 1                By living situation       NaN       NaN       NaN       NaN
# 2                      Sheltered (1)  415366.0  427971.0  391401.0  386361.0
# 3              By family arrangement       NaN       NaN       NaN       NaN
# 4                   Individuals  (1)       NaN  224293.0  213073.0  204855.0
#
#        2009      2010      2011      2012      2013      2014      2015  \
# 0  630227.0  637077.0  623788.0  621553.0  590364.0  576450.0  564708.0
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  403308.0  403543.0  392316.0  390155.0  394698.0  401051.0  391440.0
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4  215995.0  212218.0  205834.0  199159.0  203127.0  209148.0  205616.0
#
#        2016      2017      2018      2019      2020
# ...

# %% [markdown]
# Dropping any remainding NA in the data set

# %%
homeless_pop.dropna()
# Out:
#                                                Years      2005      2006  \
# 0                            Homeless population (1)  754147.0  759101.0
# 2                                      Sheltered (1)  415366.0  427971.0
# 6                                    Unsheltered (1)  338781.0  331130.0
# 8                                   Individuals  (1)  223027.0  228287.0
# 9                  People in families with childr...  115754.0  102843.0
#
#        2007      2008      2009      2010      2011      2012      2013  \
# 0  647258.0  639784.0  630227.0  637077.0  623788.0  621553.0  590364.0
# 2  391401.0  386361.0  403308.0  403543.0  392316.0  390155.0  394698.0
# 6  255857.0  253423.0  226919.0  233534.0  231472.0  231398.0  195666.0
# 8  199627.0  199670.0  176136.0  182922.0  181779.0  182997.0  165047.0
# 9   56230.0   53753.0   50783.0   50612.0   49693.0   48401.0   30619.0
#
#        2014      2015      2016      2017      2018      2019      2020
# ...

# %% [markdown]
# graphint the data with histograph

# %%
homeless_pop.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2005'}>,
#         <AxesSubplot:title={'center':'2006'}>,
#         <AxesSubplot:title={'center':'2007'}>,
#         <AxesSubplot:title={'center':'2008'}>],
#        [<AxesSubplot:title={'center':'2009'}>,
#         <AxesSubplot:title={'center':'2010'}>,
#         <AxesSubplot:title={'center':'2011'}>,
#         <AxesSubplot:title={'center':'2012'}>],
#        [<AxesSubplot:title={'center':'2013'}>,
#         <AxesSubplot:title={'center':'2014'}>,
#         <AxesSubplot:title={'center':'2015'}>,
#         <AxesSubplot:title={'center':'2016'}>],
#        [<AxesSubplot:title={'center':'2017'}>,
#         <AxesSubplot:title={'center':'2018'}>,
#         <AxesSubplot:title={'center':'2019'}>,
#         <AxesSubplot:title={'center':'2020'}>]], dtype=object)

# %%
sns.pairplot(homeless_pop)

# %% [markdown]
# Checking to see if the data has a normal distribution.

# %%
import numpy as np
import pylab
import scipy.stats as stats

# %%
homeless_pop = np.random.normal(loc = 20, scale=5, size=150)
stats.probplot(homeless_pop, dist="norm", plot=pylab)
pylab.show()

# %%
homeless_pop = np.random.normal(loc = 20, scale=5, size=150)
ax = sns.distplot(homeless_pop)
# Out:
# C:\Users\hanyu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# there is a normal distribution for the data of Homeless population in the United states.

# %% [markdown]
# to test for normality using Chi-Square

# %%
from scipy.stats import chisquare
import numpy as np

# %%
homeless_pop= np.random.normal(loc = 20, scale=5, size=150)
statistic,pvalue=chisquare(homeless_pop)
print('statistics=%.3f, p=%.3f\n' % (statistic, pvalue))
if pvalue > 0.05:
    print('Normal Distribution')
else:
    print('Not Normal Distribution')
# Out:
# statistics=133.394, p=0.816
#
# Normal Distribution
