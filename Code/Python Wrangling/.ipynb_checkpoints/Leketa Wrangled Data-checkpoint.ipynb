# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Importing Data

# %%
Veteran_homelessness = pd.read_excel("../../Data/2011-2019-PIT-Veteran-Counts-by-State.xlsx")
Veteran_homelessness.head()
# Out:
#   state Change in Veteran Homelessness, 2018-2019  \
# 0    AK                                 -0.159091
# 1    AL                                 -0.138643
# 2    AR                                 -0.051793
# 3    AZ                                  0.019037
# 4    CA                                  0.013289
#
#   Change in Veteran Homelessness, 2017-2019  \
# 0                                 -0.104839
# 1                                  0.085502
# 2                                 -0.004184
# 3                                 -0.061856
# 4                                 -0.039874
#
#   Change in Veteran Homelessness, 2016-2019  \
# 0                                 -0.339286
# 1                                 -0.217158
# 2                                  0.072072
# 3                                 -0.121622
# 4                                  0.142322
#
#   Change in Veteran Homelessness, 2015-2019  \
# 0                                 -0.383333
# ...

# %%
Veteran_homelessness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   state                                      56 non-null     object
#  1   Change in Veteran Homelessness, 2018-2019  56 non-null     object
#  2   Change in Veteran Homelessness, 2017-2019  56 non-null     object
#  3   Change in Veteran Homelessness, 2016-2019  56 non-null     object
#  4   Change in Veteran Homelessness, 2015-2019  56 non-null     object
#  5   Change in Veteran Homelessness, 2014-2019  56 non-null     object
#  6   Change in Veteran Homelessness, 2013-2019  56 non-null     object
#  7   Change in Veteran Homelessness, 2012-2019  56 non-null     object
#  8   Change in Veteran Homelessness, 2011-2019  56 non-null     object
# dtypes: object(9)
# memory usage: 4.1+ KB

# %%
Veteran_homelessness.drop(["Change in Veteran Homelessness, 2018-2019","Change in Veteran Homelessness, 2017-2019","Change in Veteran Homelessness, 2016-2019","Change in Veteran Homelessness, 2015-2019","Change in Veteran Homelessness, 2014-2019","Change in Veteran Homelessness, 2013-2019","Change in Veteran Homelessness, 2012-2019"], axis=1, inplace = True)

# %%
def Change_in_veteranR (series):
            if series == '-61.5%':
                   return -0.615

# %%
Veteran_homelessness.head()
# Out:
#   state Change in Veteran Homelessness, 2011-2019
# 0    AK                                 -0.614583
# 1    AL                                 -0.556904
# 2    AR                                 -0.420925
# 3    AZ                                  -0.40445
# 4    CA                                 -0.345767

# %%
Veteran_homelessness.dropna()
# Out:
#     state Change in Veteran Homelessness, 2011-2019
# 0      AK                                 -0.614583
# 1      AL                                 -0.556904
# 2      AR                                 -0.420925
# 3      AZ                                  -0.40445
# 4      CA                                 -0.345767
# 5      CO                                 -0.485053
# 6      CT                                 -0.559819
# 7      DC                                 -0.423301
# 8      DE                                  0.181818
# 9      FL                                 -0.562013
# 10     GA                                 -0.642889
# 11     GU                                  -0.30303
# 12     HI                                         0
# 13     IA                                 -0.441948
# 14     ID                                    -0.196
# 15     IL                                 -0.361702
# 16     IN                                  -0.19888
# ...

# %% [markdown]
# ## Histogram

# %%
Veteran_homelessness.hist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [27], in <module>
# ----> 1 Veteran_homelessness.hist()
#
# File C:\Python3\lib\site-packages\pandas\plotting\_core.py:226, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     135 """
#     136 Make a histogram of the DataFrame's columns.
#     137
#    (...)
#     223     >>> hist = df.hist(bins=3)
#     224 """
#     225 plot_backend = _get_plot_backend(backend)
# --> 226 return plot_backend.hist_frame(
#     227     data,
#     228     column=column,
#     229     by=by,
#     230     grid=grid,
#     231     xlabelsize=xlabelsize,
#     232     xrot=xrot,
#     233     ylabelsize=ylabelsize,
#     234     yrot=yrot,
#     235     ax=ax,
#     236     sharex=sharex,
#     237     sharey=sharey,
# ...

# %%
sns.pairplot(Veteran_homelessness)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <module>
# ----> 1 sns.pairplot(Veteran_homelessness)
#
# File C:\Python3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File C:\Python3\lib\site-packages\seaborn\axisgrid.py:2096, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094 # Set up the PairGrid
# ...

# %%
import numpy as np
import pylab
import scipy.stats as stats

# %%
Veteran_homelessness = np.random.normal(loc = 20, scale=5, size=150)
stats.probplot(Veteran_homelessness, dist="norm", plot=pylab)
pylab.show()

# %%
Veteran_homelessness = np.random.normal(loc = 20, scale=5, size=150)
ax = sns.distplot(Veteran_homelessness)
# Out:
# C:\Python3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from scipy.stats import chisquare
import numpy as np

# %%
Veteran_homelessness = np.random.normal(loc = 20, scale=5, size=150)
statistic,pvalue=chisquare(Veteran_homelessness)
print('statistics=%.3f, p=%.3f\n' % (statistic, pvalue))
if pvalue > 0.05:
    print('Normal Distribution')
else:
    print('Not Normal Distribution')
# Out:
# statistics=165.005, p=0.175
#
# Normal Distribution
