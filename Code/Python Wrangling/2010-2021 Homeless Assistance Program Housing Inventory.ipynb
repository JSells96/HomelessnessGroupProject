# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
coc2010 = pd.read_excel ('/Users/lakisha/Desktop/HUD 2010 CoC Homeless Assistance Program Housing Inventory Report1.xls')
coc2011 = pd.read_excel ('/Users/lakisha/Desktop/HUD 2011 CoC Homeless Assistance Program Housing Inventory Report1.xls')
coc2012 = pd.read_excel ('/Users/lakisha/Desktop/HUD 2012 CoC Homeless Assistance Program Housing Inventory Report1.xls')
coc2013 = pd.read_excel ('/Users/lakisha/Desktop/HUD 2013 CoC Homeless Assistance Program Housing Inventory Report1.xls')
coc2014 = pd.read_excel ('/Users/lakisha/Desktop/HUD 2014 CoC Homeless Assistance Program Housing Inventory Report1.xls')
coc2015 = pd.read_excel ('/Users/lakisha/Desktop/HUD 2015 CoC Homeless Assistance Program Housing Inventory Report1.xls')
coc2016 = pd.read_excel ('/Users/lakisha/Desktop/HUD 2016 CoC Homeless Assistance Program Housing Inventory Report1.xls')
coc2017 = pd.read_excel ('/Users/lakisha/Desktop/HUD 2017 CoC Homeless Assistance Program Housing Inventory Report1.xls')
coc2018 = pd.read_excel ('/Users/lakisha/Desktop/HUD 2018 CoC Homeless Assistance Program Housing Inventory Report1.xls')
coc2019 = pd.read_excel ('/Users/lakisha/Desktop/HUD 2019 CoC Homeless Assistance Program Housing Inventory Report1.xls')
coc2020 = pd.read_excel ('/Users/lakisha/Desktop/HUD 2020 CoC Homeless Assistance Program Housing Inventory Report1.xls')
coc2021 = pd.read_excel ('/Users/lakisha/Desktop/HUD 2021 CoC Homeless Assistance Program Housing Inventory Report1.xls')

# %%
print (coc2010)
print (coc2011)
print (coc2012)
print (coc2013)
print (coc2014)
print (coc2015)
print (coc2016)
print (coc2017)
print (coc2018)
print (coc2019)
print (coc2020)
print (coc2021)
# Out:
#   HUD 2010 CoC Homeless Assistance Program Housing Inventory Report  \
# 0    Emergency, Safe Haven and Transitional Housing
# 1                                 Emergency Shelter
# 2                                         Safe Haven
# 3                               Transitional Housing
# 4                                   Rapid Re-Housing
# 5                       Permanent Supportive Housing
# 6                                        Grand Total
#
#    Family Units  Family Beds  Individual Beds  Total Yr Round Beds  Seasonal  \
# 0       68063.0     217462.0           206970               424432   19668.0
# 1       32878.0     107950.0           113660               221610   19668.0
# 2           NaN          NaN             2199                 2199       NaN
# 3       35185.0     109512.0            91111               200623       NaN
# 4        5070.0      14790.0             5052                19842       NaN
# ...

# %% [markdown]
# # Merge Data

# %%
coca = pd.merge(coc2010, coc2011)
cocb = pd.merge(coca, coc2012)
cocc = pd.merge(cocb, coc2013)
cocd = pd.merge(cocc, coc2014)
coce = pd.merge(cocd, coc2015)
cocf = pd.merge(coce, coc2016)
cocg = pd.merge(cocf, coc2017)
coch = pd.merge(cocg, coc2018)
coci = pd.merge(coch, coc2019)
cocj = pd.merge(coci, coc2020)
coc2010_2021 = pd.merge(cocj, coc2021)

# %%
coc2010_2021
# Out:
# Empty DataFrame
# Columns: [HUD 2010 CoC Homeless Assistance Program Housing Inventory Report, HUD 2011 CoC Homeless Assistance Program Housing Inventory, HUD 2012 CoC Homeless Assistance Program Housing Inventory Report, HUD 2013 CoC Homeless Assistance Program Housing Inventory, HUD 2014 CoC Homeless Assistance Program Housing Inventory Report, HUD 2015 CoC Homeless Assistance Program Housing Inventory Report, HUD 2016 CoC Homeless Assistance Program Housing Inventory Report, HUD 2017 CoC Homeless Assistance Program Housing Inventory, HUD 2018 CoC Homeless Assistance Program Housing Inventory Report, HUD 2019 CoC Homeless Assistance Program Housing Inventory Report, HUD 2020 CoC Homeless Assistance Program Housing Inventory Report, HUD 2021 CoC Homeless Assistance Program Housing Inventory Report, Family Units, Family Beds, Individual Beds, Adult Only Beds, Child Only Beds, Total Yr Round Beds, Seasonal, Overflow/Voucher, Veteran Beds, Youth Beds]
# Index: []
#
# ...

# %%
coc2010_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 22 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   HUD 2010 CoC Homeless Assistance Program Housing Inventory Report  0 non-null      object
#  1   HUD 2011 CoC Homeless Assistance Program Housing Inventory         0 non-null      object
#  2   HUD 2012 CoC Homeless Assistance Program Housing Inventory Report  0 non-null      object
#  3   HUD 2013 CoC Homeless Assistance Program Housing Inventory         0 non-null      object
#  4   HUD 2014 CoC Homeless Assistance Program Housing Inventory Report  0 non-null      object
#  5   HUD 2015 CoC Homeless Assistance Program Housing Inventory Report  0 non-null      object
#  6   HUD 2016 CoC Homeless Assistance Program Housing Inventory Report  0 non-null      object
# ...

# %% [markdown]
# # Drop NA

# %%
coc2010_2021.dropna()
# Out:
# Empty DataFrame
# Columns: [HUD 2010 CoC Homeless Assistance Program Housing Inventory Report, HUD 2011 CoC Homeless Assistance Program Housing Inventory, HUD 2012 CoC Homeless Assistance Program Housing Inventory Report, HUD 2013 CoC Homeless Assistance Program Housing Inventory, HUD 2014 CoC Homeless Assistance Program Housing Inventory Report, HUD 2015 CoC Homeless Assistance Program Housing Inventory Report, HUD 2016 CoC Homeless Assistance Program Housing Inventory Report, HUD 2017 CoC Homeless Assistance Program Housing Inventory, HUD 2018 CoC Homeless Assistance Program Housing Inventory Report, HUD 2019 CoC Homeless Assistance Program Housing Inventory Report, HUD 2020 CoC Homeless Assistance Program Housing Inventory Report, HUD 2021 CoC Homeless Assistance Program Housing Inventory Report, Family Units, Family Beds, Individual Beds, Adult Only Beds, Child Only Beds, Total Yr Round Beds, Seasonal, Overflow/Voucher, Veteran Beds, Youth Beds]
# Index: []
#
# ...

# %% [markdown]
# # Histogram

# %%
coc2010_2021.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Family Units'}>,
#         <AxesSubplot:title={'center':'Family Beds'}>,
#         <AxesSubplot:title={'center':'Individual Beds'}>],
#        [<AxesSubplot:title={'center':'Adult Only Beds'}>,
#         <AxesSubplot:title={'center':'Child Only Beds'}>,
#         <AxesSubplot:title={'center':'Total Yr Round Beds'}>],
#        [<AxesSubplot:title={'center':'Seasonal'}>,
#         <AxesSubplot:title={'center':'Overflow/Voucher'}>,
#         <AxesSubplot:title={'center':'Veteran Beds'}>],
#        [<AxesSubplot:title={'center':'Youth Beds'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.pairplot(coc2010_2021)

# %%
import pylab
import scipy.stats as stats

# %% [markdown]
# # Checking for Normal Distribution

# %%
coc2010_2021 = np.random.normal(loc = 20, scale=5, size=150)
stats.probplot(coc2010_2021, dist="norm", plot=pylab)
pylab.show()

# %%
coc2010_2021 = np.random.normal(loc = 20, scale=5, size=150)
ax = sns.distplot(coc2010_2021)
# Out:
# /Users/lakisha/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from scipy.stats import chisquare
import numpy as np

# %% [markdown]
# # There is not a normal distribution for HUD 2010 - 2021 CoC Homeless Assistance Program Housing in the United states.
# Test for normality using Chi-Square

# %%
coc2010_2021= np.random.normal(loc = 20, scale=5, size=150)
statistic,pvalue=chisquare(coc2010_2021)
print('statistics=%.3f, p=%.3f\n' % (statistic, pvalue))
if pvalue > 0.05:
    print('Normal Distribution')
else:
    print('Not Normal Distribution')
# Out:
# statistics=185.794, p=0.022
#
# Not Normal Distribution
