# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
TYR2010_2021 = pd.read_excel ('../../Data/2010-2021 Total Year Round.xlsx')

# %%
TYR2010_2021.head()
# Out:
#                                     Total Yr Round    2010    2011    2012  \
# 0  Emergency, Safe Haven and Transitional Housing   424432  429692  428527
# 1                               Emergency Shelter   221610  225831  229206
# 2                                       Safe Haven    2199    2116    2129
# 3                             Transitional Housing  200623  201745  197192
# 4                                Permanent Housing       0       0       0
#
#      2013    2014    2015    2016    2017    2018    2019    2020    2021
# 0  446078  424880  426267  411285  399439  389622  389549  396149  396466
# 1  238708  249497  264440  264629  277537  286203  291837  301589  307908
# 2    2191    2159    2043    1907    1653    2390    2266    2302    2487
# 3  205179  173224  159784  144749  120249  101029   95446   92258   86071
# 4       0  347908  403853  455817  499620  507271  522108  545722  567771

# %%
TYR2010_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Total Yr Round  9 non-null      object
#  1   2010            9 non-null      int64
#  2   2011            9 non-null      int64
#  3   2012            9 non-null      int64
#  4   2013            9 non-null      int64
#  5   2014            9 non-null      int64
#  6   2015            9 non-null      int64
#  7   2016            9 non-null      int64
#  8   2017            9 non-null      int64
#  9   2018            9 non-null      int64
#  10  2019            9 non-null      int64
#  11  2020            9 non-null      int64
#  12  2021            9 non-null      int64
# dtypes: int64(12), object(1)
# memory usage: 1.0+ KB

# %%
TYR2010_2021.corr(method='pearson')
# Out:
#           2010      2011      2012      2013      2014      2015      2016  \
# 2010  1.000000  0.998243  0.998607  0.998496  0.888363  0.860051  0.825226
# 2011  0.998243  1.000000  0.999499  0.997321  0.891341  0.865779  0.833863
# 2012  0.998607  0.999499  1.000000  0.999047  0.892953  0.866732  0.834435
# 2013  0.998496  0.997321  0.999047  1.000000  0.892184  0.864248  0.830544
# 2014  0.888363  0.891341  0.892953  0.892184  1.000000  0.997268  0.989158
# 2015  0.860051  0.865779  0.866732  0.864248  0.997268  1.000000  0.997194
# 2016  0.825226  0.833863  0.834435  0.830544  0.989158  0.997194  1.000000
# 2017  0.793166  0.803989  0.804271  0.799183  0.977776  0.990501  0.997868
# 2018  0.774922  0.786641  0.787049  0.781610  0.971150  0.985647  0.994733
# 2019  0.772339  0.784997  0.785085  0.778997  0.968403  0.983870  0.993861
# 2020  0.763771  0.776839  0.776630  0.770081  0.964322  0.981055  0.992128
# ...

# %%
TYR2010_2021.corr(method = 'pearson').style.format("{:2}").background_gradient(cmap=plt.get_cmap('coolwarm'),axis=1)
# Out:
# <style type="text/css">
# #T_4cfe4_row0_col0, #T_4cfe4_row1_col1, #T_4cfe4_row1_col2, #T_4cfe4_row2_col1, #T_4cfe4_row2_col2, #T_4cfe4_row3_col3, #T_4cfe4_row4_col4, #T_4cfe4_row5_col5, #T_4cfe4_row6_col6, #T_4cfe4_row7_col7, #T_4cfe4_row8_col8, #T_4cfe4_row8_col9, #T_4cfe4_row8_col10, #T_4cfe4_row9_col8, #T_4cfe4_row9_col9, #T_4cfe4_row9_col10, #T_4cfe4_row10_col8, #T_4cfe4_row10_col9, #T_4cfe4_row10_col10, #T_4cfe4_row10_col11, #T_4cfe4_row11_col9, #T_4cfe4_row11_col10, #T_4cfe4_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4cfe4_row0_col1, #T_4cfe4_row0_col2, #T_4cfe4_row0_col3, #T_4cfe4_row1_col0, #T_4cfe4_row2_col0, #T_4cfe4_row2_col3, #T_4cfe4_row3_col0, #T_4cfe4_row3_col2, #T_4cfe4_row7_col8, #T_4cfe4_row7_col9, #T_4cfe4_row8_col7, #T_4cfe4_row9_col7, #T_4cfe4_row9_col11, #T_4cfe4_row11_col8 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_4cfe4_row0_col4 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_4cfe4_row0_col5 {
# ...
