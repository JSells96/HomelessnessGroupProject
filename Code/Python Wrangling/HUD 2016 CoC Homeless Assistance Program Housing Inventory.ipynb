# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Importing Data

# %%
coc2016 = pd.read_excel ('/Users/lakisha/Desktop/HUD 2016 CoC Homeless Assistance Program Housing Inventory Report.xls')

# %%
coc2016.head()
# Out:
#   HUD 2016 CoC Homeless Assistance Program Housing Inventory Report  \
# 0    Emergency, Safe Haven and Transitional Housing
# 1                                 Emergency Shelter
# 2                                         Safe Haven
# 3                               Transitional Housing
# 4                                  Permanent Housing
#
#    Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0     63870.0    209122.0      198247      3916.0      411285     21358.0
# 1     39603.0    133523.0      128315      2791.0      264629     21358.0
# 2         NaN         NaN        1907         NaN        1907         NaN
# 3     24267.0     75599.0       68025      1125.0      144749         NaN
# 4     68784.0    204104.0      251606       107.0      455817         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0     17446.0       22585       11679
# 1     17446.0        4543        3459
# 2         NaN         333          31
# ...

# %%
coc2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 10 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   HUD 2016 CoC Homeless Assistance Program Housing Inventory Report  9 non-null      object
#  1   Unnamed: 1                                                         8 non-null      float64
#  2   Unnamed: 2                                                         8 non-null      float64
#  3   Unnamed: 3                                                         9 non-null      int64
#  4   Unnamed: 4                                                         8 non-null      float64
#  5   Unnamed: 5                                                         9 non-null      int64
#  6   Unnamed: 6                                                         3 non-null      float64
# ...

# %% [markdown]
# # Dropping NA

# %%
coc2016.dropna()
# Out:
#   HUD 2016 CoC Homeless Assistance Program Housing Inventory Report  \
# 0    Emergency, Safe Haven and Transitional Housing
# 1                                 Emergency Shelter
# 8                                        Grand Total
#
#    Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0     63870.0    209122.0      198247      3916.0      411285     21358.0
# 1     39603.0    133523.0      128315      2791.0      264629     21358.0
# 8    132654.0    413226.0      449853      4023.0      867102     21358.0
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0     17446.0       22585       11679
# 1     17446.0        4543        3459
# 8     17446.0      129290       17180

# %% [markdown]
# # Histogram

# %%
coc2016.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 1'}>,
#         <AxesSubplot:title={'center':'Unnamed: 2'}>,
#         <AxesSubplot:title={'center':'Unnamed: 3'}>],
#        [<AxesSubplot:title={'center':'Unnamed: 4'}>,
#         <AxesSubplot:title={'center':'Unnamed: 5'}>,
#         <AxesSubplot:title={'center':'Unnamed: 6'}>],
#        [<AxesSubplot:title={'center':'Unnamed: 7'}>,
#         <AxesSubplot:title={'center':'Unnamed: 8'}>,
#         <AxesSubplot:title={'center':'Unnamed: 9'}>]], dtype=object)

# %%
sns.pairplot(coc2016)

# %%
import pylab
import scipy.stats as stats

# %% [markdown]
# # Checking for Normal Distribution

# %%
coc2016 = np.random.normal(loc = 20, scale=5, size=150)
stats.probplot(coc2016, dist="norm", plot=pylab)
pylab.show()

# %%
coc2016 = np.random.normal(loc = 20, scale=5, size=150)
ax = sns.distplot(coc2016)
# Out:
# /Users/lakisha/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from scipy.stats import chisquare
import numpy as np

# %% [markdown]
# # There is a normal distribution for HUD 2016 CoC Homeless Assistance Program Housing in the United states.
# Test for normality using Chi-Square

# %%
coc2016= np.random.normal(loc = 20, scale=5, size=150)
statistic,pvalue=chisquare(coc2016)
print('statistics=%.3f, p=%.3f\n' % (statistic, pvalue))
if pvalue > 0.05:
    print('Normal Distribution')
else:
    print('Not Normal Distribution')
# Out:
# statistics=160.461, p=0.246
#
# Normal Distribution
