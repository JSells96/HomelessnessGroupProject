# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
from scipy import stats
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Data

# %%
RandomTotalYr = pd.read_excel ('../../Data/Total Year Round Random.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/k5/m__j_rf50m1cdnhnvfxrq4y80000gn/T/ipykernel_21890/976661164.py in <module>
# ----> 1 RandomTotalYr = pd.read_excel ('../../Data/Total Year Round Random.xlsx')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
RandomTotalYr.head()
# Out:
#    Unnamed: 0  California  Texas  New York  Florida  Louisiana  Illinois
# 0        2010       92829  31029    100080    34074       8664     24557
# 1        2011       96844  34673    105227    37282       8869     24946
# 2        2012      100757  33551     99791    37445       8992     26494
# 3        2013       87044  33974    108274    38884       9394     24341
# 4        2014       95752  37496    114667    40068       9697     25690

# %%
RandomTotalYr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  12 non-null     int64
#  1   California  12 non-null     int64
#  2   Texas       12 non-null     int64
#  3   New York    12 non-null     int64
#  4   Florida     12 non-null     int64
#  5   Louisiana   12 non-null     int64
#  6   Illinois    12 non-null     int64
# dtypes: int64(7)
# memory usage: 800.0 bytes

# %%
RandomTotalYr.head()
# Out:
#    Unnamed: 0  California  Texas  New York  Florida  Louisiana  Illinois
# 0        2010       92829  31029    100080    34074       8664     24557
# 1        2011       96844  34673    105227    37282       8869     24946
# 2        2012      100757  33551     99791    37445       8992     26494
# 3        2013       87044  33974    108274    38884       9394     24341
# 4        2014       95752  37496    114667    40068       9697     25690

# %% [markdown]
# # Heatmap Correlation

# %%
sns.heatmap(RandomTotalYr.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Pearson Correlation

# %%
RandomTotalYr.corr(method='pearson')
# Out:
#             Unnamed: 0  California     Texas  New York   Florida  Louisiana  \
# Unnamed: 0    1.000000    0.924218  0.947812  0.946742  0.882993   0.861669
# California    0.924218    1.000000  0.868953  0.822688  0.694943   0.683747
# Texas         0.947812    0.868953  1.000000  0.904149  0.870582   0.813136
# New York      0.946742    0.822688  0.904149  1.000000  0.933705   0.832029
# Florida       0.882993    0.694943  0.870582  0.933705  1.000000   0.913930
# Louisiana     0.861669    0.683747  0.813136  0.832029  0.913930   1.000000
# Illinois      0.889472    0.936344  0.843522  0.764539  0.731135   0.757484
#
#             Illinois
# Unnamed: 0  0.889472
# California  0.936344
# Texas       0.843522
# New York    0.764539
# Florida     0.731135
# Louisiana   0.757484
# Illinois    1.000000

# %%
RandomTotalYr.corr(method = 'pearson').style.format("{:2}").background_gradient(cmap=plt.get_cmap('coolwarm'),axis=1)
# Out:
# <style type="text/css">
# #T_a1e50_row0_col0, #T_a1e50_row1_col1, #T_a1e50_row2_col2, #T_a1e50_row3_col3, #T_a1e50_row4_col4, #T_a1e50_row5_col5, #T_a1e50_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a1e50_row0_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_a1e50_row0_col2 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_a1e50_row0_col3, #T_a1e50_row4_col0 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_a1e50_row0_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_a1e50_row0_col5, #T_a1e50_row1_col5, #T_a1e50_row2_col5, #T_a1e50_row3_col6, #T_a1e50_row4_col1, #T_a1e50_row5_col1, #T_a1e50_row6_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a1e50_row0_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_a1e50_row1_col0 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_a1e50_row1_col2 {
#   background-color: #efcebd;
#   color: #000000;
# }
# ...

# %% [markdown]
# # Spearman Correlation

# %%
RandomTotalYr.corr(method='spearman')
# Out:
#             Unnamed: 0  California     Texas  New York   Florida  Louisiana  \
# Unnamed: 0    1.000000    0.923077  0.930070  0.951049  0.811189   0.860140
# California    0.923077    1.000000  0.874126  0.867133  0.734266   0.755245
# Texas         0.930070    0.874126  1.000000  0.888112  0.755245   0.734266
# New York      0.951049    0.867133  0.888112  1.000000  0.797203   0.811189
# Florida       0.811189    0.734266  0.755245  0.797203  1.000000   0.895105
# Louisiana     0.860140    0.755245  0.734266  0.811189  0.895105   1.000000
# Illinois      0.874126    0.937063  0.783217  0.762238  0.692308   0.790210
#
#             Illinois
# Unnamed: 0  0.874126
# California  0.937063
# Texas       0.783217
# New York    0.762238
# Florida     0.692308
# Louisiana   0.790210
# Illinois    1.000000

# %%
RandomTotalYr.corr(method = 'spearman').style.format("{:2}").background_gradient(cmap=plt.get_cmap('coolwarm'),axis=1)
# Out:
# <style type="text/css">
# #T_a08cb_row0_col0, #T_a08cb_row1_col1, #T_a08cb_row2_col2, #T_a08cb_row3_col3, #T_a08cb_row4_col4, #T_a08cb_row5_col5, #T_a08cb_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a08cb_row0_col1, #T_a08cb_row6_col0 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_a08cb_row0_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_a08cb_row0_col3 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_a08cb_row0_col4, #T_a08cb_row1_col4, #T_a08cb_row2_col5, #T_a08cb_row3_col6, #T_a08cb_row4_col6, #T_a08cb_row5_col2, #T_a08cb_row6_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a08cb_row0_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_a08cb_row0_col6 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_a08cb_row1_col0 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_a08cb_row1_col2, #T_a08cb_row2_col1 {
#   background-color: #e3d9d3;
# ...
