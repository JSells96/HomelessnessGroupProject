# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import metrics
import numpy as np

# %%
coc2010 = pd.read_excel ('/Users/lakisha/Desktop/Data Science/HUD 2010 CoC Homeless Assistance Program Housing Inventory Report.xlsx')
coc2015 = pd.read_excel ('/Users/lakisha/Desktop/Data Science/HUD 2015 CoC Homeless Assistance Program Housing Inventory Report.xlsx')
coc2018 = pd.read_excel ('/Users/lakisha/Desktop/Data Science/HUD 2018 CoC Homeless Assistance Program Housing Inventory Report.xlsx')
coc2019 = pd.read_excel ('/Users/lakisha/Desktop/Data Science/HUD 2019 CoC Homeless Assistance Program Housing Inventory Report.xlsx')
coc2020 = pd.read_excel ('/Users/lakisha/Desktop/Data Science/HUD 2020 CoC Homeless Assistance Program Housing Inventory Report.xlsx')
coc2021 = pd.read_excel ('/Users/lakisha/Desktop/Data Science/HUD 2021 CoC Homeless Assistance Program Housing Inventory Report.xlsx')

# %%
print (coc2010)
print (coc2015)
print (coc2018)
print (coc2019)
print (coc2020)
print (coc2021)
# Out:
#   HUD 2010 CoC Homeless Assistance Program Housing Inventory Report  \
# 0    Emergency, Safe Haven and Transitional Housing
# 1                                 Emergency Shelter
# 2                                         Safe Haven
# 3                               Transitional Housing
# 4                                   Rapid Re-Housing
# 5                       Permanent Supportive Housing
# 6                                        Grand Total
#
#    Family Units  Family Beds  Individual Beds  Total Yr Round Beds  Seasonal  \
# 0       68063.0     217462.0           206970               424432   19668.0
# 1       32878.0     107950.0           113660               221610   19668.0
# 2           NaN          NaN             2199                 2199       NaN
# 3       35185.0     109512.0            91111               200623       NaN
# 4        5070.0      14790.0             5052                19842       NaN
# ...

# %%
coc1 = pd.merge(coc2010, coc2015)

# %%
coc2 = pd.merge(coc1, coc2018)

# %%
coc3 = pd.merge(coc2, coc2019)

# %%
coc4 = pd.merge(coc3, coc2020)

# %%
coc5 = pd.merge(coc4, coc2021)

# %%
coc5
# Out:
# Empty DataFrame
# Columns: [HUD 2010 CoC Homeless Assistance Program Housing Inventory Report, HUD 2015 CoC Homeless Assistance Program Housing Inventory Report, HUD 2018 CoC Homeless Assistance Program Housing Inventory Report, HUD 2019 CoC Homeless Assistance Program Housing Inventory Report, HUD 2020 CoC Homeless Assistance Program Housing Inventory Report, HUD 2021 CoC Homeless Assistance Program Housing Inventory Report, Family Units, Family Beds, Individual Beds, Adult Only Beds, Child Only Beds, Total Yr Round Beds, Seasonal, Overflow/Voucher, Veteran Beds, Youth Beds]
# Index: []

# %%
x = coc5 [['Family Beds', 'Indivual Beds']]
y = coc5 [['Adult Beds', 'Child Only Beds']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/k5/m__j_rf50m1cdnhnvfxrq4y80000gn/T/ipykernel_57310/1128379744.py in <module>
# ----> 1 x = coc5 [['Family Beds', 'Indivual Beds']]
#       2 y = coc5 [['Adult Beds', 'Child Only Beds']]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
# ...
